# %%
user_ages = [10, 18, 21, 35, 42, 27, 12, 16]


print(*[i for i in user_ages if i>18], sep='\n')
# Out:
# 21
# 35
# 42
# 27

# %%
user_ages = [10, 18, 21, 35, 42, 27, 12, 16]

for i in user_ages:
    if i >18:
        print(i)
# Out:
# 21
# 35
# 42
# 27

# %%
lst=[]
N=10
while len(lst) != 6:
    for i in range(N):
        if i==0 or i%2==0:
            lst.append(i)
print(n)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

# %%
df= pd.read_excel('/content/drive/MyDrive/PROJECT/twst.xlsx')

# %%
df= pd.read_excel('/content/drive/MyDrive/PROJECT/twst.xlsx')

# %%
df
# Out:
#       Record_ID       Дата  Контрагент  КТ Сумма
# 0      ID_16858 2018-01-12         100  32864.15
# 1      ID_16859 2018-02-13         100  10664.94
# 2      ID_16860 2018-03-14         100  60299.15
# 3      ID_16861 2018-04-13         100  30706.06
# 4      ID_16862 2018-05-14         100  57450.12
# ...         ...        ...         ...       ...
# 15899  ID_33465 2019-11-29         996  49147.97
# 15900  ID_33466 2019-02-15         997  16159.15
# 15901  ID_33467 2019-03-14         997   9963.90
# 15902  ID_33469 2019-02-20         999  25000.00
# 15903  ID_33470 2019-10-08         999  26000.00
#
# [15904 rows x 4 columns]

# %%
df.shape
# Out:
# (15904, 4)

# %%
df.describe()
# Out:
#          Контрагент      КТ Сумма
# count  15904.000000  15904.000000
# mean     355.904678  18856.962876
# std      385.934024  21197.220637
# min        2.000000      0.010000
# 25%      112.000000   4020.000000
# 50%      191.000000  11456.770000
# 75%      477.000000  24173.390000
# max     1748.000000  99996.000000

# %%
df.columns
# Out:
# Index(['Record_ID', 'Дата', 'Контрагент', 'КТ Сумма'], dtype='object')

# %%
df=df.rename(columns={'Record_ID': 'Number_id', 'Дата': 'Date', 'Контрагент': 'Counterparty', 'КТ Сумма': 'Sum_Transactrion'})

# %%
df.head()
# Out:
#   Number_id       Date  Counterparty  Sum_Transactrion
# 0  ID_16858 2018-01-12           100          32864.15
# 1  ID_16859 2018-02-13           100          10664.94
# 2  ID_16860 2018-03-14           100          60299.15
# 3  ID_16861 2018-04-13           100          30706.06
# 4  ID_16862 2018-05-14           100          57450.12

# %%
df[['Number_id', 'Date']].head()
# Out:
#   Number_id       Date
# 0  ID_16858 2018-01-12
# 1  ID_16859 2018-02-13
# 2  ID_16860 2018-03-14
# 3  ID_16861 2018-04-13
# 4  ID_16862 2018-05-14

# %%
all_money=df.Sum_Transactrion.sum()

# %%
all_money
# Out:
# 299901137.58

# %%
money_by=df.groupby(['Counterparty', 'Date'], as_index=False).aggregate({'Sum_Transactrion':'sum'}).sort_values('Sum_Transactrion', ascending=False)

# %%
money_by.to_excel('money_by.xlsx', index=False)

# %%
money_by=df.query('Sum_Transactrion < 50000').groupby(['Counterparty', 'Date'], as_index=False).aggregate({'Sum_Transactrion':'sum', 'Number_id':'count'}).sort_values('Sum_Transactrion', ascending=False)

# %%
bmoney_by
# Out:
#       Counterparty       Date  Sum_Transactrion  Number_id
# 2891           133 2019-02-18         534311.41         24
# 2958           136 2018-04-05         321294.11         37
# 4609           209 2019-05-24         315455.00         14
# 7040           535 2020-08-17         295486.00         14
# 338             15 2020-01-09         293000.00         12
# ...            ...        ...               ...        ...
# 2978           141 2019-01-25              0.10          1
# 2979           141 2019-07-05              0.10          1
# 3065           144 2018-02-14              0.09          1
# 2981           141 2019-08-27              0.08          1
# 2965           139 2018-07-23              0.02          2
#
# [9545 rows x 4 columns]

# %% [markdown]
# 1 Задание/Урок 1

# %%
import pandas as pd

# %%
path_to_file=pd.read_csv('/content/drive/MyDrive/PROJECT/2_taxi_nyc.csv')

# %%
path_to_file.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
path_to_file.shape
# Out:
# (29101, 14)

# %%
path_to_file.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
path_to_file.head(100)
# Out:
#               pickup_dt pickup_month        borough  pickups hday  spd   vsb  \
# 0   2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0  10.0
# 1   2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0  10.0
# 2   2015-01-01 01:00:00          Jan            EWR        0    Y  5.0  10.0
# 3   2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0  10.0
# 4   2015-01-01 01:00:00          Jan         Queens      405    Y  5.0  10.0
# ..                  ...          ...            ...      ...  ...  ...   ...
# 95  2015-01-01 15:00:00          Jan            EWR        0    Y  6.0  10.0
# 96  2015-01-01 15:00:00          Jan      Manhattan     1143    Y  6.0  10.0
# 97  2015-01-01 15:00:00          Jan         Queens      219    Y  6.0  10.0
# 98  2015-01-01 15:00:00          Jan  Staten Island        4    Y  6.0  10.0
# 99  2015-01-01 15:00:00          Jan            NaN        2    Y  6.0  10.0
#
# ...

# %%
taxi=path_to_file.rename(columns={'pcp 01': 'pcp_01', 'pcp 06':'pcp_06', 'pcp 24':'pcp_24'})

# %%
taxi.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
taxi['borough'].value_counts()
# Out:
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: borough, dtype: int64

# %%
taxi.groupby('borough').pickups.sum()
# Out:
# borough
# Bronx              220047
# Brooklyn          2321035
# EWR                   105
# Manhattan        10367841
# Queens            1343528
# Staten Island        6957
# Name: pickups, dtype: int64

# %%
min_pickups=taxi.groupby(['borough','hday']).agg({'pickups':'mean'})

# %%
min_pickups
# Out:
#                         pickups
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %%
pickups_by_mon_bor=taxi.groupby(['pickup_month','borough'], as_index=False).agg({'pickups':'sum'}).sort_values('pickups',ascending=False )

# %%
pickups_by_mon_bor
# Out:
#    pickup_month        borough  pickups
# 21          Jun      Manhattan  1995388
# 33          May      Manhattan  1888800
# 9           Feb      Manhattan  1718571
# 27          Mar      Manhattan  1661261
# 3           Apr      Manhattan  1648278
# 15          Jan      Manhattan  1455543
# 19          Jun       Brooklyn   482466
# 31          May       Brooklyn   476087
# 1           Apr       Brooklyn   378095
# 25          Mar       Brooklyn   346726
# 7           Feb       Brooklyn   328650
# 13          Jan       Brooklyn   309011
# 22          Jun         Queens   286311
# 34          May         Queens   275893
# 28          Mar         Queens   219561
# 4           Apr         Queens   216857
# 10          Feb         Queens   185695
# 16          Jan         Queens   159211
# 30          May          Bronx    53037
# 18          Jun          Bronx    49006
# 0           Apr          Bronx    34617
# 24          Mar          Bronx    32232
# ...

# %%
def temp_to_celcius(tempa):
  return (tempa-32)*5
temp_to_celcius(taxi['temp'])
# Out:
# 0        -10.0
# 1        -10.0
# 2        -10.0
# 3        -10.0
# 4        -10.0
#          ...
# 29096    215.0
# 29097    215.0
# 29098    215.0
# 29099    215.0
# 29100    215.0
# Name: temp, Length: 29101, dtype: float64

# %%
taxi['temp_C'] = temp_to_celcius(taxi['temp'])
taxi['temp_C'][:5]
# Out:
# 0   -10.0
# 1   -10.0
# 2   -10.0
# 3   -10.0
# 4   -10.0
# Name: temp_C, dtype: float64

# %%
import pandas as pd

# %%
bookings=pd.read_csv('/content/drive/MyDrive/PROJECT/2_bookings.csv', sep=';')

# %%
bookings_head=bookings.head(7)

# %%
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings.columns
# Out:
# Index(['Hotel', 'Is Canceled', 'Lead Time', 'arrival full date',
#        'Arrival Date Year', 'Arrival Date Month', 'Arrival Date Week Number',
#        'Arrival Date Day of Month', 'Stays in Weekend nights',
#        'Stays in week nights', 'stays total nights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'Reserved Room Type', 'Assigned room type',
#        'customer type', 'Reservation Status', 'Reservation status_date'],
#       dtype='object')

# %%
for i in bookings.columns:
  print(i)
# Out:
# Hotel
# Is Canceled
# Lead Time
# arrival full date
# Arrival Date Year
# Arrival Date Month
# Arrival Date Week Number
# Arrival Date Day of Month
# Stays in Weekend nights
# Stays in week nights
# stays total nights
# Adults
# Children
# Babies
# Meal
# Country
# Reserved Room Type
# Assigned room type
# customer type
# Reservation Status
# Reservation status_date

# %%
bookings.columns = [col.lower().replace('_','') for col in bookings.columns]

# %%
bookings
# Out:
#                hotel  is canceled  lead time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival date year arrival date month  arrival date week number  \
# 0                    2015               July                        27
# ...

# %%
bookings
# Out:
#                hotel  is canceled  lead time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival date year arrival date month  arrival date week number  \
# 0                    2015               July                        27
# ...

# %%
bookings=pd.read_csv('/content/drive/MyDrive/PROJECT/2_bookings.csv', sep=';')

# %%
bookings.columns = [col.lower().replace(' ','_') for col in bookings.columns]

# %%
booking=bookings.query("reservation_status != is_canceled")
booking['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
groupbook=booking.groupby('hotel', as_index=False).agg({'stays_total_nights':'mean'}).round(2)

# %%
groupbook
# Out:
#           hotel  stays_total_nights
# 0    City Hotel                2.98
# 1  Resort Hotel                4.32

# %%
booking.query("arrival_date_year == 2017")["arrival_date_month"].value_counts()
# Out:
# May         6313
# April       5661
# June        5647
# July        5313
# March       4970
# August      4925
# February    4177
# January     3681
# Name: arrival_date_month, dtype: int64

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking.query("is_canceled == 1 and hotel == 'City Hotel'").groupby('arrival_date_year')['arrival_date_month'].value_counts()
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             1543
#                    October               1321
#                    August                1232
#                    July                   939
#                    December               668
#                    November               301
# 2016               October               1947
#                    June                  1720
#                    September             1567
#                    April                 1539
#                    May                   1436
#                    November              1360
#                    August                1247
#                    March                 1108
#                    December              1072
#                    July                  1043
#                    February               930
#                    January                438
# 2017               May                   2217
#                    April                 1926
# ...

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking[['children', 'adults', 'babies']].mean().idxmax()
# Out:
# 'adults'

# %%
booking['total_kids']=booking.children+booking.babies
booking.groupby('hotel').agg({'total_kids':'mean'})
# Out:
#               total_kids
# hotel
# City Hotel      0.096311
# Resort Hotel    0.142586

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking['had_kids']= booking['total_kids'] >=1

# %%
booking.query('is_canceled == 1')['had_kids'].value_counts()/booking['had_kids'].value_counts()
# Out:
# False    0.372213
# True     0.349228
# Name: had_kids, dtype: float64

# %% [markdown]
# 2 УРОК PANDAS

# %%
import pandas as pd
companies=pd.read_csv('/content/drive/MyDrive/PROJECT/3_companies.csv', sep=';')

# %%
companies
# Out:
#                                   company       income        date
# 0    ЗАО «Доронин, Колобов и Калашникова»   1221331958  2019-09-09
# 1                            ООО «Авдеев»  21116804375  1972-12-21
# 2                  РАО «Аксенов Сорокина»  79257158759  2007-03-05
# 3                  Ларионов Инкорпорэйтед  36799366126  2011-08-11
# 4                 Григорьев Инкорпорэйтед  48201837498  1989-09-02
# ..                                    ...          ...         ...
# 288                            Сэтл групп   6152279994  2004-03-30
# 289                  ОАО «Горшков Чернов»  26623978007  2004-03-30
# 290                          НПО «Фадеев»  84314056422  1998-09-03
# 291                    Петролеум Трейдинг  95528839292  1975-01-31
# 292                         ОАО «Жданова»  40620723709  2016-04-19
#
# [293 rows x 3 columns]

# %%
def read_n_agg(comp):
  return comp.groupby('company', as_index=True).agg({'income': 'mean'})
read_n_agg(companies)
# Out:
#                                                 income
# company
# En +                                      9.962187e+10
# АО «Александрова, Савельев и Мельникова»  7.206782e+10
# АО «Андреев-Анисимов»                     6.931948e+09
# АО «Андреев-Макарова»                     8.934380e+10
# АО «Большаков Кошелева»                   7.860861e+10
# ...                                                ...
# Щекиноазот                                4.309092e+10
# Щукин Лимитед                             6.703036e+10
# Эйвон Бьюти Продактс Компани (Avon)       2.503657e+10
# Яковлева Инкорпорэйтед                    3.523436e+10
# Якушев Лимитед                            3.876468e+10
#
# [289 rows x 1 columns]

# %%
taxi=pd.read_csv('/content/drive/MyDrive/PROJECT/3_taxi_peru.csv', sep=';', parse_dates=['start_at', 'end_at', 'arrived_at'])

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxii=taxi['source'].value_counts(normalize=True).round(2)
taxii
# Out:
# iPhone     0.42
# web        0.33
# Android    0.21
# iPad       0.02
# Wap        0.01
# Name: source, dtype: float64

# %%
taxii=taxi['source'].value_counts()
taxii
# Out:
# iPhone     9741
# web        7631
# Android    4909
# iPad        571
# Wap         136
# Name: source, dtype: int64

# %%
grouptaxi=taxi.groupby('icon', as_index=False).agg({'user_id':'count'}).rename(columns={'user_id':'count'})
grouptaxi
# Out:
#         icon  count
# 0       easy    135
# 1  executive  22737
# 2      group    239

# %%
import seaborn as sns
sns.barplot(data=grouptaxi, x='icon', y='count')
# Out:
# <Axes: xlabel='icon', ylabel='count'>

# %%
sns.countplot(data= taxi, hue='end_state', x='source')
# Out:
# <Axes: xlabel='source', ylabel='count'>

# %%
driver_score_counts=taxi['driver_score'].value_counts(normalize=True).mul(100).round(2).reset_index(drop=False).rename(columns={'index':'driver_score', 'driver_score': 'percentage'}).sort_values('driver_score', ascending=True)

# %%
driver_score_counts
# Out:
#    driver_score  percentage
# 2           0.0       14.30
# 4           1.0        1.23
# 5           2.0        0.81
# 3           3.0        2.97
# 1           4.0       21.88
# 0           5.0       58.81

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.barplot(x='driver_score', y='percentage', data=driver_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='Driver score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %%
driver_score_counts=taxi['rider_score'].value_counts(normalize=True).mul(100).round(2).reset_index(drop=False).rename(columns={'index':'rider_score', 'rider_score': 'percentage'}).sort_values('rider_score', ascending=True)
ax = sns.barplot(x='rider_score', y='percentage', data=driver_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='Rider score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %%
logs=pd.read_csv('/content/drive/MyDrive/PROJECT/3_logs.csv')
user_data=pd.read_csv('/content/drive/MyDrive/PROJECT/3_user_data.csv')
logs['platform'].nunique()
# Out:
# 3

# %%
logs
# Out:
#       client  success  platform        time
# 0      40177     True     phone  1585412212
# 1      61468     True     phone  1585425658
# 2      35604    False     phone  1585459894
# 3       9961     True     phone  1585400189
# 4      10931     True  computer  1585468629
# ...      ...      ...       ...         ...
# 4495   64496    False  computer  1585459072
# 4496   73299     True     phone  1585458370
# 4497    8967     True     phone  1585465121
# 4498   52880    False     phone  1585455362
# 4499   40921     True     phone  1585437692
#
# [4500 rows x 4 columns]

# %%
selected_logs=logs.query('success==True', as_index=False).groupby('client').agg({'client':'count'})

# %%
selected_logs
# Out:
#         client
# client
# 40           1
# 50           1
# 75           1
# 81           1
# 132          1
# ...        ...
# 99926        1
# 99927        1
# 99931        1
# 99973        1
# 99993        1
#
# [2845 rows x 1 columns]

# %% [markdown]
# КУРС:Введение с DS-Практика

# %%
import pandas as pd
import numpy as np

# %%
student=pd.read_csv('/content/drive/MyDrive/PROJECT/StudentsPerformance.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
student.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
student.groupby('gender').agg({'math score':'mean'})
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %%
student.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
student_selected=student.iloc[[0, 3, 4, 7, 8]]

# %%
student_selected.index=['nigga', 'nigger', 'niggger',' nigggggger', 'niggggggger']

# %%
student_selected
# Out:
#              gender race/ethnicity parental level of education         lunch  \
# nigga        female        group B           bachelor's degree      standard
# nigger         male        group A          associate's degree  free/reduced
# niggger        male        group C                some college      standard
#  nigggggger    male        group B                some college  free/reduced
# niggggggger    male        group D                 high school  free/reduced
#
#             test preparation course  math score  reading score  writing score
# nigga                          none          72             72             74
# nigger                         none          47             57             44
# niggger                        none          76             78             75
#  nigggggger                    none          40             43             39
# niggggggger               completed          64             64             67

# %%
student_selected.loc[['nigger'], ['gender']]
# Out:
#        gender
# nigger   male

# %%
student_selected.iloc[:, 0]
# Out:
# nigga          female
# nigger           male
# niggger          male
#  nigggggger      male
# niggggggger      male
# Name: gender, dtype: object

# %%
my_series = pd.Series([4, 5, 6],index=['nigga', 'nigger', 'niggger'])
my_series_1= pd.Series([4, 5, 6],index=['nigga', 'nigger', 'niggger'])

# %%
my_series
# Out:
# nigga      4
# nigger     5
# niggger    6
# dtype: int64

# %%
pd.DataFrame({'niggaFrame':my_series, 'nigga_frame_2':my_series_1})
# Out:
#          niggaFrame  nigga_frame_2
# nigga             4              4
# nigger            5              5
# niggger           6              6

# %%
student.head
# Out:
# <bound method NDFrame.head of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student.iloc[0:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
student.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
titanic=pd.read_csv('/content/drive/MyDrive/PROJECT/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.shape
# Out:
# (891, 12)

# %%
student.loc[student.gender == 'female', ['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 5    female          71
# 6    female          88
# ..      ...         ...
# 993  female          62
# 995  female          88
# 997  female          59
# 998  female          68
# 999  female          77
#
# [518 rows x 2 columns]

# %%
mean_writing_score=student['writing score'].mean()

# %%
mean_writing_score
# Out:
# 68.054

# %%
student.loc[student['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student['lunch'].value_counts(normalize=True).describe
# Out:
# <bound method NDFrame.describe of standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64>

# %%
student.groupby('lunch').aggregate({'math score':['count', 'mean', 'std'], 'reading score':['count', 'mean', 'std'], 'writing score' :['count', 'mean', 'std']})
# Out:
#              math score                       reading score             \
#                   count       mean        std         count       mean
# lunch
# free/reduced        355  58.921127  15.159956           355  64.653521
# standard            645  70.034109  13.653501           645  71.654264
#
#                         writing score
#                     std         count       mean        std
# lunch
# free/reduced  14.895339           355  63.022535  15.433823
# standard      13.830602           645  70.823256  14.339487

# %%
students_performance = student\
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
writing=10

# %%
students_performance.query('writing_score < @writing')
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental_level_of_education, lunch, test_preparation_course, math_score, reading_score, writing_score]
# Index: []

# %%
hell=pd.read_csv('/content/drive/MyDrive/PROJECT/column_hell.csv')

# %%
hell
# Out:
#        yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0   0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1   0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2   0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
# 3   0.857910  0.555818  0.598305  0.473988  0.784139  0.427963  0.725103
# 4   0.748652  0.451725  0.252619  0.584361  0.011265  0.051115  0.755444
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.665300  0.744322  0.377087  0.809735  0.220817  0.248306  0.131914
# 96  0.344394  0.182979  0.590196  0.483025  0.474131  0.031048  0.672095
# 97  0.694568  0.507591  0.328004  0.333993  0.091637  0.356788  0.541017
# 98  0.692840  0.220333  0.729843  0.202430  0.360106  0.980271  0.913669
# 99  0.391447  0.989147  0.011527  0.894302  0.669284  0.158220  0.283287
#
#     ijvnixxo  kudbpyw-3    upubjv  ...        fi   clsruyy       g&6  \
# ...

# %%
hell.describe
# Out:
# <bound method NDFrame.describe of        yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0   0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1   0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2   0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
# 3   0.857910  0.555818  0.598305  0.473988  0.784139  0.427963  0.725103
# 4   0.748652  0.451725  0.252619  0.584361  0.011265  0.051115  0.755444
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.665300  0.744322  0.377087  0.809735  0.220817  0.248306  0.131914
# 96  0.344394  0.182979  0.590196  0.483025  0.474131  0.031048  0.672095
# 97  0.694568  0.507591  0.328004  0.333993  0.091637  0.356788  0.541017
# 98  0.692840  0.220333  0.729843  0.202430  0.360106  0.980271  0.913669
# 99  0.391447  0.989147  0.011527  0.894302  0.669284  0.158220  0.283287
#
# ...

# %%
selected_columns = hell.filter(like='-')

# %%
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.groupby(['gender','race/ethnicity'], as_index=False).agg({'math_score':'mean', 'reading_score':'mean'})
# Out:
#    gender race/ethnicity  math_score  reading_score
# 0  female        group A   58.527778      69.000000
# 1  female        group B   61.403846      71.076923
# 2  female        group C   62.033333      71.944444
# 3  female        group D   65.248062      74.046512
# 4  female        group E   70.811594      75.840580
# 5    male        group A   63.735849      61.735849
# 6    male        group B   65.930233      62.848837
# 7    male        group C   67.611511      65.424460
# 8    male        group D   69.413534      66.135338
# 9    male        group E   76.746479      70.295775

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance['total_score'] = students_performance.reading_score+ students_performance.math_score+students_performance.writing_score

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students_performance=students_performance.assign(total_score_log = np.log(students_performance.total_score))

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students_performance.drop(['total_score'], axis =1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota=pd.read_csv('/content/drive/MyDrive/PROJECT/dota_hero_stats.csv')

# %%
dota.groupby('legs').agg({'legs':'count'})
# Out:
#       legs
# legs
# 0       11
# 2       95
# 4        7
# 6        3
# 8        1

# %%
lupa=pd.read_csv('/content/drive/MyDrive/PROJECT/accountancy.csv')

# %%
lupa
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
lupa.groupby(['Executor', 'Type'], as_index=False
            ).agg({'Salary':'mean'})
# Out:
#    Executor Type      Salary
# 0     Loopa    A   58.000000
# 1     Loopa    B  145.166667
# 2     Loopa    C  154.333333
# 3     Loopa    D  137.714286
# 4     Loopa    E  164.000000
# 5     Loopa    F  238.000000
# 6      Pupa    A  160.833333
# 7      Pupa    B   77.000000
# 8      Pupa    C   74.500000
# 9      Pupa    D  146.500000
# 10     Pupa    E  131.200000
# 11     Pupa    F  136.250000

# %%
lupa.pivot_table(values = "Salary", index = "Executor", columns = "Type")
# Out:
# Type               A           B           C           D      E       F
# Executor
# Loopa      58.000000  145.166667  154.333333  137.714286  164.0  238.00
# Pupa      160.833333   77.000000   74.500000  146.500000  131.2  136.25

# %%
dota.groupby(['attack_type', 'primary_attr'], as_index=False).agg({'id':'count'}).sort_values('id', ascending=False)
# Out:
#   attack_type primary_attr  id
# 4      Ranged          int  40
# 2       Melee          str  35
# 0       Melee          agi  19
# 3      Ranged          agi  18
# 5      Ranged          str   3
# 1       Melee          int   2

# %%
vod=pd.read_csv('/content/drive/MyDrive/PROJECT/algae.csv')

# %%
vod
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
vod.arond(cinc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-dda6ca5aeeda> in <cell line: 1>()
# ----> 1 vod.arond(cinc)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'arond'

# %%
vod.query('genus == "Fucus"').describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
vod.groupby('group').agg({'citrate':'var'})
# Out:
#         citrate
# group
# brown  5.468942
# green  3.950113
# red         NaN

# %%
vod
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
student
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-98eabfd95b2a> in <cell line: 1>()
# ----> 1 student
#
# NameError: name 'student' is not defined

# %%
students_performance.plot.scatter(x='math_score', y='reading_score')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-059a72839978> in <cell line: 1>()
# ----> 1 students_performance.plot.scatter(x='math_score', y='reading_score')
#
# NameError: name 'students_performance' is not defined

# %%
ax=sns.lmplot(x='math_score', y='reading_score',hue='gender', data=students_performance, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
incomes=pd.read_csv('/content/drive/MyDrive/PROJECT/income.csv')
incomes

# %%
plt.plot(incomes.index, incomes.income)

# %%
df = pd.read_csv("/content/drive/MyDrive/PROJECT/dataset_209770_6.txt", sep=" ")
df

# %%
df.plot.scatter(x='x', y='y')

# %%
genom=pd.read_csv('/content/drive/MyDrive/PROJECT/genome_matrix.csv', index_col=0)

# %%
karta=sns.heatmap(data=genom, cmap='viridis')
karta.xaxis.set_ticks_position('top')
karta.xaxis.set_tick_params(rotation=90)

# %%
dota['roles'].agg((lambda x: len(x.split(','))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-91f5227cd2cc> in <cell line: 1>()
# ----> 1 dota['roles'].agg((lambda x: len(x.split(','))))
#
# NameError: name 'dota' is not defined

# %%
cvet=pd.read_csv('/content/drive/MyDrive/PROJECT/iris.csv', index_col=0)

# %%
cvet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1996949ff70a> in <cell line: 1>()
# ----> 1 cvet
#
# NameError: name 'cvet' is not defined

# %%
for xx in cvet:
  sns.displot(cvet[xx])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cdbd0b7d09b4> in <cell line: 1>()
# ----> 1 for xx in cvet:
#       2   sns.displot(cvet[xx])
#
# NameError: name 'cvet' is not defined

# %%
sns.violinplot(y='petal length', data=cvet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e3f0b5710ba1> in <cell line: 1>()
# ----> 1 sns.violinplot(y='petal length', data=cvet)
#
# NameError: name 'cvet' is not defined

# %%
sns.pairplot(data=cvet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-58e2a51b5cef> in <cell line: 1>()
# ----> 1 sns.pairplot(data=cvet)
#
# NameError: name 'cvet' is not defined

# %%
import pandas as pd
d={'type':['A','A','B','B'], 'number':[10, 14, 12, 23]}
df=pd.DataFrame(data=d)

# %%
df
# Out:
#   type  number
# 0    A      10
# 1    A      14
# 2    B      12
# 3    B      23

# %%
my_state = pd.read_csv("/content/drive/MyDrive/PROJECT/my_stat.csv")
my_state
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
subset_1=my_state.iloc[0:9, [0,2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B

# %%
my_state.drop([0, 4]).iloc[:,[1,3]]
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
subset_1=my_state.query('V1>0 and V3=="A"')

# %%
subset_2=my_state.query('V2 != 10 or V4>=1')
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
import numpy as np
import pandas as pd

# %%
my_state['V5']=my_state.V1+my_state.V2
my_state['V6']=np.log(my_state.V2)
my_state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ddc4114226e> in <cell line: 1>()
# ----> 1 my_state['V5']=my_state.V1+my_state.V2
#       2 my_state['V6']=np.log(my_state.V2)
#       3 my_state
#
# NameError: name 'my_state' is not defined

# %%
my_state=my_state.assign(V5 = my_state.V1+my_state.V4, V6 = np.log(my_state.V2))
my_state

# %%
my_state=my_state.rename(columns={'V1': 'session_value', 'V2': 'group', 'V3': 'time', 'V4': 'n_users'})
my_state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-10e1fe17f65b> in <cell line: 1>()
# ----> 1 my_state=my_state.rename(columns={'V1': 'session_value', 'V2': 'group', 'V3': 'time', 'V4': 'n_users'})
#       2 my_state
#
# NameError: name 'my_state' is not defined

# %%
my_data=pd.read_csv('/content/drive/MyDrive/PROJECT/my_stat_1 (1).csv')

# %%
my_data
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_data['session_value']=my_data['session_value'].fillna(0)

# %%
my_data.loc[my_data['n_users'] < 0, 'n_users']=my_data[my_data.n_users >= 0.0].n_users.median()

# %%
my_data.groupby(['group'], as_index=False).agg({'session_value':'mean'}).rename(columns={'session_value':'mean_session_value'})
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8

# %%
from scipy.stats import stats

A = """X Y
4 2
5 1
2 4
3 3
1 5"""

x, y = [], []

[(x.append(int(a[0])), y.append(int(a[2]))) for a in A.split('\n') if a[0].isdigit()]

print(stats.pearsonr(x,y)[0])
# Out:
# -1.0
# <ipython-input-1-53cf8dd6e733>:14: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   print(stats.pearsonr(x,y)[0])
