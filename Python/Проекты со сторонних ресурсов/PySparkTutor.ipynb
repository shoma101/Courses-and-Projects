# %% [markdown]
# part 1

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425345 sha256=c558b6b8e7f0a47b7fc377b5a4b3dc69870c41d91799205fb3a52720d572cee9
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test1.csv')

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()

# %%
df_pyspark = spark.read.option('header', 'true').csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test1.csv', inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', age=31, Experience=10, Salary=30000),
#  Row(Name='Sudhanshu', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %% [markdown]
# part 2

# %%
spark = SparkSession.builder.appName('DataFrame').getOrCreate()

# %%
df_spark = spark.read.option('header', 'true').csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test1.csv', inferSchema = True)

# %%
df_spark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test1.csv', header=True, inferSchema=False)

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', age='31', Experience='10', Salary='30000'),
#  Row(Name='Sudhanshu', age='30', Experience='8', Salary='25000'),
#  Row(Name='Sunny', age='29', Experience='4', Salary='20000')]

# %%
df_pyspark.columns
# Out:
# ['Name', 'age', 'Experience', 'Salary']

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'),
#  ('age', 'string'),
#  ('Experience', 'string'),
#  ('Salary', 'string')]

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.select(['Name', 'Experience']).show()
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |    Krish|        10|
# |Sudhanshu|         8|
# |    Sunny|         4|
# |     Paul|         3|
# |   Harsha|         1|
# |  Shubham|         2|
# +---------+----------+

# %%
df_spark.describe().show()
# Out:
# +-------+------+------------------+-----------------+------------------+
# |summary|  Name|               age|       Experience|            Salary|
# +-------+------+------------------+-----------------+------------------+
# |  count|     6|                 6|                6|                 6|
# |   mean|  NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev|  NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|Harsha|                21|                1|             15000|
# |    max| Sunny|                31|               10|             30000|
# +-------+------+------------------+-----------------+------------------+

# %%
df_pyspark=df_pyspark.withColumn('Experience after 2 years', df_pyspark['Experience']+2)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+------------------------+
# |     Name|age|Experience|Salary|Experience after 2 years|
# +---------+---+----------+------+------------------------+
# |    Krish| 31|        10| 30000|                    12.0|
# |Sudhanshu| 30|         8| 25000|                    10.0|
# |    Sunny| 29|         4| 20000|                     6.0|
# |     Paul| 24|         3| 20000|                     5.0|
# |   Harsha| 21|         1| 15000|                     3.0|
# |  Shubham| 23|         2| 18000|                     4.0|
# +---------+---+----------+------+------------------------+

# %%
df_pyspark=df_pyspark.drop('Experience after 2 years')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.withColumnRenamed('Name', 'New_Name').show()
# Out:
# +---------+---+----------+------+
# | New_Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# 3 part

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Practise').getOrCreate()

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test2.csv', header=True, inferSchema=False)

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.drop('Name').show()
# Out:
# +----+----------+------+
# | age|Experience|Salary|
# +----+----------+------+
# |  31|        10| 30000|
# |  30|         8| 25000|
# |  29|         4| 20000|
# |  24|         3| 20000|
# |  21|         1| 15000|
# |  23|         2| 18000|
# |NULL|      NULL| 40000|
# |  34|        10| 38000|
# |  36|      NULL|  NULL|
# +----+----------+------+

# %%
df_pyspark.na.drop().show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.na.drop(how='all').show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how='all', thresh=1).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how='any', subset='age').show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |     NULL| 34|        10| 38000|
# |     NULL| 36|      NULL|  NULL|
# +---------+---+----------+------+

# %%
df_pyspark.na.fill('Missing Value',subset='age')
# Out:
# DataFrame[Name: string, age: string, Experience: string, Salary: string]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(
    inputCols=['age', 'Experience', 'Salary'],
    outputCols=["{}_imputed".format(c) for c in ['age', 'Experience', 'Salary']]
    ).setStrategy("mode")

# %%
# Add imputation cols to df
imputer.fit(df_pyspark).transform(df_pyspark).show()
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-65-514a2e384c2d> in <cell line: 2>()
#       1 # Add imputation cols to df
# ----> 2 imputer.fit(df_pyspark).transform(df_pyspark).show()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     203                 return self.copy(params)._fit(dataset)
#     204             else:
# --> 205                 return self._fit(dataset)
#     206         else:
#     207             raise TypeError(
#
# /usr/local/lib/python3.10/dist-packages/pyspark/ml/wrapper.py in _fit(self, dataset)
#     379
#     380     def _fit(self, dataset: DataFrame) -> JM:
# --> 381         java_model = self._fit_java(dataset)
#     382         model = self._create_model(java_model)
#     383         return self._copyValues(model)
#
# ...

# %% [markdown]
# Tutor 4

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('dataframe').getOrCreate()

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test2.csv',header=True, inferSchema=True)

# %%
df_pyspark = df_pyspark.na.drop(how='all', thresh=4)

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_pyspark.filter("Salary<=20000").select(['Name', 'age']).show()
# Out:
# +-------+---+
# |   Name|age|
# +-------+---+
# |  Sunny| 29|
# |   Paul| 24|
# | Harsha| 21|
# |Shubham| 23|
# +-------+---+

# %%
df_pyspark.filter((df_pyspark['Salary']<=20000)&(df_pyspark['age']>23)).show()
# Out:
# +-----+---+----------+------+
# | Name|age|Experience|Salary|
# +-----+---+----------+------+
# |Sunny| 29|         4| 20000|
# | Paul| 24|         3| 20000|
# +-----+---+----------+------+

# %%
spark = SparkSession.builder.appName('Agg').getOrCreate()

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test3.csv',header=True, inferSchema=True)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- salary: integer (nullable = true)

# %%
df_pyspark.groupBy('Name').sum().show(
)
# Out:
# +---------+-----------+
# |     Name|sum(salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %%
spark = SparkSession.builder.appName('Missing').getOrCreate()

# %%
training = spark.read.csv('/content/drive/MyDrive/WORKING/Курсы и проекты/Python/Проекты со сторонних ресурсов/Дата-сеты для проектов /test1.csv',header=True, inferSchema=True)

# %%
training.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
from pyspark.ml.feature import VectorAssembler

# %%
featureassembler = VectorAssembler(inputCols = ['age', 'Experience'], outputCol = 'Independent Features')

# %%
output = featureassembler.transform(training)

# %%
output.show()
# Out:
# +---------+---+----------+------+--------------------+
# |     Name|age|Experience|Salary|Independent Features|
# +---------+---+----------+------+--------------------+
# |    Krish| 31|        10| 30000|         [31.0,10.0]|
# |Sudhanshu| 30|         8| 25000|          [30.0,8.0]|
# |    Sunny| 29|         4| 20000|          [29.0,4.0]|
# |     Paul| 24|         3| 20000|          [24.0,3.0]|
# |   Harsha| 21|         1| 15000|          [21.0,1.0]|
# |  Shubham| 23|         2| 18000|          [23.0,2.0]|
# +---------+---+----------+------+--------------------+

# %%
finalized_data = output.select('Independent Features', 'Salary')

# %%
finalized_data.show()
# Out:
# +--------------------+------+
# |Independent Features|Salary|
# +--------------------+------+
# |         [31.0,10.0]| 30000|
# |          [30.0,8.0]| 25000|
# |          [29.0,4.0]| 20000|
# |          [24.0,3.0]| 20000|
# |          [21.0,1.0]| 15000|
# |          [23.0,2.0]| 18000|
# +--------------------+------+

# %%
from pyspark.ml.regression import LinearRegression
train_data, test_data = finalized_data.randomSplit([0.75, 0.25])
regressor = LinearRegression(featuresCol='Independent Features', labelCol='Salary')
regressor = regressor.fit(train_data)

# %%
regressor.coefficients
# Out:
# DenseVector([-176.3341, 1320.1856])

# %%
regressor.intercept
# Out:
# 19812.064965197555

# %%
pred_results = regressor.evaluate(test_data)

# %%
pred_results.predictions.show()
# Out:
# +--------------------+------+------------------+
# |Independent Features|Salary|        prediction|
# +--------------------+------+------------------+
# |          [21.0,1.0]| 15000|17429.234338747123|
# |         [31.0,10.0]| 30000|27547.563805104444|
# +--------------------+------+------------------+

# %%
pred_results.meanAbsoluteError, pred_results.meanSquaredError
# Out:
# (2440.8352668213392, 5957811.381290981)
